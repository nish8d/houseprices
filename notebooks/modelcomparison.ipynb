# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
results = pd.DataFrame({
    'Model': ['Linear Regression', 'Lasso', 'Ridge', 'ElasticNet', 'Random Forest', 'XGBoost'],
    'RMSE': [33412.53, 33549.32, 32223.08, 31367.18, 29532.77, 27526.19],
    'MAE':  [20200.18, 20194.97, 19456.62, 18445.85, 17481.37, 16473.99],
    'R2':   [0.8545, 0.8533, 0.8646, 0.8717, 0.8863, 0.9012]
})

results.sort_values(by='RMSE', ascending=True, inplace=True)
results.reset_index(drop=True, inplace=True)
results
# Out:
#                Model      RMSE       MAE      R2
# 0            XGBoost  27526.19  16473.99  0.9012
# 1      Random Forest  29532.77  17481.37  0.8863
# 2         ElasticNet  31367.18  18445.85  0.8717
# 3              Ridge  32223.08  19456.62  0.8646
# 4  Linear Regression  33412.53  20200.18  0.8545
# 5              Lasso  33549.32  20194.97  0.8533

# %%
new_row = pd.DataFrame({
    'Model': ['Stacked Model'],
    'RMSE': [25080.49],
    'MAE': [14222.66],
    'R2': [0.9180]
})

results = pd.concat([results, new_row], ignore_index=True)
results.sort_values(by='RMSE', inplace=True)
results.reset_index(drop=True, inplace=True)

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='RMSE', hue='Model', data=results, palette='coolwarm')

plt.title('Model Comparison - RMSE (Lower is Better)')
plt.xlabel('RMSE')
plt.ylabel('Model')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='MAE', hue='Model', data=results, palette='mako')
plt.title('Model Comparison - MAE (Lower is Better)')
plt.xlabel('MAE')
plt.ylabel('Model')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='R2', hue='Model', data=results, palette='viridis')
plt.title('Model Comparison - R² (Higher is Better)')
plt.xlabel('R² Score')
plt.ylabel('Model')
plt.grid(True)
plt.show()
